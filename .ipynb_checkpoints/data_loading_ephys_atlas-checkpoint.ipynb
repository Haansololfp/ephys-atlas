# %%
import pandas as pd

from pathlib import Path
from one.remote import aws
from one.api import ONE

# %%
LOCAL_DATA_PATH = Path("/media/cat/julien/ephys_atlas_decoder/data")

# %%
# The AWS private credentials are stored in Alyx, so that only one authentication is required
one = ONE(base_url="https://alyx.internationalbrainlab.org", mode='online')
s3, bucket_name = aws.get_s3_from_alyx(alyx=one.alyx)
aws.s3_download_folder("aggregates/bwm",
                       LOCAL_DATA_PATH,
                       s3=s3, bucket_name=bucket_name)
# Out:
# [PosixPath('/media/cat/julien/ephys_atlas_decoder/data/2022_W34/channels.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/2022_W34/clusters.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/2022_W34/depths.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/2022_W34/probes.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/2022_W34/raw_ephys_features.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/2022_W39/channels.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/2022_W39/clusters.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/2022_W39/depths.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/2022_W39/probes.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/2022_W39_test/channels.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/2022_W39_test/clusters.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/2022_W39_test/depths.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/2022_W39_test/probes.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/channels.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/clusters.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/depths.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/df_save_goodunit_ins_region.csv'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/latest/channels.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/latest/clusters.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/latest/depths.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/latest/df_save_goodunit_ins_region.csv'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/latest/probes.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/latest/raw_ephys_features.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/latest/xyz_picks.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/probes.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/raw_ephys_features.pqt'),
#  PosixPath('/media/cat/julien/ephys_atlas_decoder/data/xyz_picks.pqt')]

# %%
df_clusters = pd.read_parquet(LOCAL_DATA_PATH.joinpath('clusters.pqt'))
df_probes = pd.read_parquet(LOCAL_DATA_PATH.joinpath('probes.pqt'))
df_channels = pd.read_parquet(LOCAL_DATA_PATH.joinpath('channels.pqt'))
df_depths = pd.read_parquet(LOCAL_DATA_PATH.joinpath('depths.pqt'))
df_voltage = pd.read_parquet(LOCAL_DATA_PATH.joinpath('raw_ephys_features.pqt'))

## %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure()
sns.countplot(data=df_probes, x='histology', palette='deep')

plt.figure()
sns.countplot(data=df_clusters, x='label',  palette='deep')
# Out:
# <AxesSubplot: xlabel='label', ylabel='count'>

# %%
df_voltage
# Out:
#                                                 rms_lf   psd_delta  \
# pid                                  raw_ind
# f336f6a4-f693-4b88-b12c-c5cf0785b061 0        0.000090  -94.020044
#                                      1        0.000089  -94.239377
#                                      2        0.000088  -94.322141
#                                      3        0.000088  -94.338916
#                                      4        0.000087  -94.506565
# ...                                                ...         ...
# 17f738d1-b16d-4cd3-8c52-77b08ad2e37f 379      0.000568  -94.123103
#                                      380      0.000048 -101.653320
#                                      381      0.000044 -102.880308
#                                      382      0.000046 -102.449089
#                                      383      0.000045 -103.285468
#
#                                                psd_theta   psd_alpha  \
# pid                                  raw_ind
# f336f6a4-f693-4b88-b12c-c5cf0785b061 0        -93.508149  -96.389494
#                                      1        -93.656290  -96.530573
#                                      2        -93.686909  -96.698530
#                                      3        -93.719757  -96.653027
#                                      4        -93.833626  -96.853400
# ...                                                  ...         ...
# 17f738d1-b16d-4cd3-8c52-77b08ad2e37f 379      -89.899695  -91.657917
#                                      380     -100.937274 -102.755558
#                                      381     -101.741580 -103.216843
#                                      382     -101.381428 -103.354616
#                                      383     -101.888934 -103.785816
#
#                                                 psd_beta   psd_gamma  \
# pid                                  raw_ind
# f336f6a4-f693-4b88-b12c-c5cf0785b061 0       -101.040683 -104.508322
#                                      1       -101.085805 -104.523240
#                                      2       -101.382672 -104.745460
#                                      3       -101.256453 -104.605760
#                                      4       -101.536338 -104.755873
# ...                                                  ...         ...
# 17f738d1-b16d-4cd3-8c52-77b08ad2e37f 379      -95.204774  -83.710302
#                                      380     -105.752082 -107.967440
#                                      381     -106.086336 -109.542340
#                                      382     -106.125546 -108.924410
#                                      383     -106.190550 -108.379910
#
#                                                 rms_ap  alpha_mean  \
# pid                                  raw_ind
# f336f6a4-f693-4b88-b12c-c5cf0785b061 0        0.000011  273.719827
#                                      1        0.000018   91.555660
#                                      2        0.000016   82.886347
#                                      3        0.000010  141.028329
#                                      4        0.000013   61.489926
# ...                                                ...         ...
# 17f738d1-b16d-4cd3-8c52-77b08ad2e37f 379      0.000011   59.006454
#                                      380      0.000011  208.753526
#                                      381      0.000011  247.539127
#                                      382      0.000010  173.076169
#                                      383      0.000011  251.508174
#
#                                                alpha_std  spike_rate  \
# pid                                  raw_ind
# f336f6a4-f693-4b88-b12c-c5cf0785b061 0               NaN    0.033333
#                                      1         44.031195    1.033330
#                                      2         30.855219    0.133333
#                                      3        123.006064    0.066666
#                                      4               NaN    0.033333
# ...                                                  ...         ...
# 17f738d1-b16d-4cd3-8c52-77b08ad2e37f 379       43.368531    6.933333
#                                      380       41.263593    0.116667
#                                      381      225.469916    2.833333
#                                      382      102.233976    0.916667
#                                      383      194.610495    0.150000
#
#                                               cloud_x_std  cloud_y_std  \
# pid                                  raw_ind
# f336f6a4-f693-4b88-b12c-c5cf0785b061 0                NaN          NaN
#                                      1          19.748135    19.332491
#                                      2           1.308343     6.919840
#                                      3          17.386815    34.052760
#                                      4                NaN          NaN
# ...                                                   ...          ...
# 17f738d1-b16d-4cd3-8c52-77b08ad2e37f 379         8.254311     9.720044
#                                      380         9.979912    14.746358
#                                      381        18.565437    21.559591
#                                      382        17.141697     8.704943
#                                      383        22.342174    12.808072
#
#                                               cloud_z_std
# pid                                  raw_ind
# f336f6a4-f693-4b88-b12c-c5cf0785b061 0                NaN
#                                      1          22.658410
#                                      2           7.817002
#                                      3          12.115384
#                                      4                NaN
# ...                                                   ...
# 17f738d1-b16d-4cd3-8c52-77b08ad2e37f 379         7.321092
#                                      380        19.226490
#                                      381        15.191684
#                                      382        18.516492
#                                      383        25.302019
#
# [226944 rows x 13 columns]

# %%
df_clusters.columns
# Out:
# Index(['channels', 'depths', 'cluster_id', 'amp_max', 'amp_min', 'amp_median',
#        'amp_std_dB', 'contamination', 'contamination_alt', 'drift',
#        'missed_spikes_est', 'noise_cutoff', 'presence_ratio',
#        'presence_ratio_std', 'slidingRP_viol', 'spike_count', 'firing_rate',
#        'label', 'ks2_label', 'x', 'y', 'z', 'acronym', 'atlas_id', 'axial_um',
#        'lateral_um', 'pid'],
#       dtype='object')

# %%
df_clusters["drift"]
# Out:
# 0          83355.825544
# 1          26919.325458
# 2         140802.056479
# 3           1071.722941
# 4           1127.562561
#               ...
# 304735      4911.017782
# 304736      7448.524478
# 304737      6200.610117
# 304738     10042.191907
# 304739       635.544550
# Name: drift, Length: 304740, dtype: float64

# %%
df_probes
# Out:
#                                                                        eid  \
# 00b05238-aa75-4846-a480-c5ffef4529dc  258b4a8b-28e3-4c18-9f86-1ea2bc0dc806
# 5877f7c5-e08b-422f-bfb3-ce0b3a795fc8  258b4a8b-28e3-4c18-9f86-1ea2bc0dc806
# 1a2698b5-26b9-4670-b54b-a094daac82ec  c7e4e6ad-280f-432f-ac85-9be299890d6e
# 23207e4e-1a41-411c-a60e-4b1aa82b7a7c  c7e4e6ad-280f-432f-ac85-9be299890d6e
# 754713ae-8ea8-4d49-99ba-2ca2213f6c80  d62a64f4-fdc6-448b-8f2a-53ed08d645a7
# ...                                                                    ...
# 958b1089-a066-43e2-990d-8aad703429a2  49368f16-de69-4647-9a7a-761e94517821
# 3283d8ec-1436-4529-8a16-941bbf65c91d  5139ce2c-7d52-44bf-8129-692d61dd6403
# eb82b081-4edc-4d6a-89ee-3453d1c4c8f0  5139ce2c-7d52-44bf-8129-692d61dd6403
# 0fed7207-f747-428b-b4c0-854cabb50d9e  1211f4af-d3e4-4c4e-9d0b-75a0bc2bf1f0
# 17f738d1-b16d-4cd3-8c52-77b08ad2e37f  1211f4af-d3e4-4c4e-9d0b-75a0bc2bf1f0
#
#                                         pname            spike_sorter  \
# 00b05238-aa75-4846-a480-c5ffef4529dc  probe00  alf/probe00/pykilosort
# 5877f7c5-e08b-422f-bfb3-ce0b3a795fc8  probe01  alf/probe01/pykilosort
# 1a2698b5-26b9-4670-b54b-a094daac82ec  probe00  alf/probe00/pykilosort
# 23207e4e-1a41-411c-a60e-4b1aa82b7a7c  probe01  alf/probe01/pykilosort
# 754713ae-8ea8-4d49-99ba-2ca2213f6c80  probe00  alf/probe00/pykilosort
# ...                                       ...                     ...
# 958b1089-a066-43e2-990d-8aad703429a2  probe00  alf/probe00/pykilosort
# 3283d8ec-1436-4529-8a16-941bbf65c91d  probe00  alf/probe00/pykilosort
# eb82b081-4edc-4d6a-89ee-3453d1c4c8f0  probe01  alf/probe01/pykilosort
# 0fed7207-f747-428b-b4c0-854cabb50d9e  probe01  alf/probe01/pykilosort
# 17f738d1-b16d-4cd3-8c52-77b08ad2e37f  probe00  alf/probe00/pykilosort
#
#                                      histology
# 00b05238-aa75-4846-a480-c5ffef4529dc   aligned
# 5877f7c5-e08b-422f-bfb3-ce0b3a795fc8   aligned
# 1a2698b5-26b9-4670-b54b-a094daac82ec   aligned
# 23207e4e-1a41-411c-a60e-4b1aa82b7a7c   aligned
# 754713ae-8ea8-4d49-99ba-2ca2213f6c80   aligned
# ...                                        ...
# 958b1089-a066-43e2-990d-8aad703429a2   aligned
# 3283d8ec-1436-4529-8a16-941bbf65c91d       alf
# eb82b081-4edc-4d6a-89ee-3453d1c4c8f0   aligned
# 0fed7207-f747-428b-b4c0-854cabb50d9e   aligned
# 17f738d1-b16d-4cd3-8c52-77b08ad2e37f   aligned
#
# [592 rows x 4 columns]
